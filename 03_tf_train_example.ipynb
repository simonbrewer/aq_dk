# %% [markdown]
# # Simple regression with TensorFlow

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.13.1

# %%
X = np.load("./rbfs/phi_reduce.npy")
y = np.load("./rbfs/y.npy")

# %%
X = X[0:100000, :]
y = y[0:100000]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    train_size = 0.8, random_state=42)

# %% [markdown]
# ## TensorFlow

# %%
X.shape
# Out:
# (51821, 201)

# %%
# Set random seed
tf.random.set_seed(42)

# Create a model using the Sequential API
model = tf.keras.Sequential([
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(1, activation='linear')
])

model = tf.keras.Sequential([
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(1, activation='linear')
])

# %%
# Compile the model
model.compile(loss=tf.keras.losses.mae, # mae is short for mean absolute error
              #optimizer=tf.keras.optimizers.SGD(learning_rate=0.01), # SGD is short for stochastic gradient descent
              #optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001), # SGD is short for stochastic gradient descent
              metrics=["mae"])

# %%
# Fit the model
model.fit(X_test, y_test, epochs=50, shuffle=True, batch_size=128) # this will break with TensorFlow 2.7.0+
# model.fit(tf.expand_dims(X, axis=-1), y, epochs=5)#
# Out:
# Epoch 1/50
# 81/81 [==============================] - 0s 669us/step - loss: 0.0557 - mae: 0.0557
# Epoch 2/50
# 81/81 [==============================] - 0s 584us/step - loss: 0.0267 - mae: 0.0267
# Epoch 3/50
# 81/81 [==============================] - 0s 600us/step - loss: 0.0173 - mae: 0.0173
# Epoch 4/50
# 81/81 [==============================] - 0s 595us/step - loss: 0.0135 - mae: 0.0135
# Epoch 5/50
# 81/81 [==============================] - 0s 1ms/step - loss: 0.0122 - mae: 0.0122
# Epoch 6/50
# 81/81 [==============================] - 0s 622us/step - loss: 0.0112 - mae: 0.0112
# Epoch 7/50
# 81/81 [==============================] - 0s 813us/step - loss: 0.0108 - mae: 0.0108
# Epoch 8/50
# 81/81 [==============================] - 0s 606us/step - loss: 0.0107 - mae: 0.0107
# Epoch 9/50
# 81/81 [==============================] - 0s 594us/step - loss: 0.0105 - mae: 0.0105
# Epoch 10/50
# 81/81 [==============================] - 0s 581us/step - loss: 0.0105 - mae: 0.0105
# Epoch 11/50
# 81/81 [==============================] - 0s 610us/step - loss: 0.0104 - mae: 0.0104
# Epoch 12/50
# 81/81 [==============================] - 0s 596us/step - loss: 0.0104 - mae: 0.0104
# Epoch 13/50
# 81/81 [==============================] - 0s 603us/step - loss: 0.0104 - mae: 0.0104
# Epoch 14/50
# 81/81 [==============================] - 0s 621us/step - loss: 0.0103 - mae: 0.0103
# Epoch 15/50
# 81/81 [==============================] - 0s 640us/step - loss: 0.0103 - mae: 0.0103
# Epoch 16/50
# 81/81 [==============================] - 0s 606us/step - loss: 0.0103 - mae: 0.0103
# 81/81 [==============================] - 0s 581us/step - loss: 0.0102 - mae: 0.0102
# Epoch 50/50
# 81/81 [==============================] - 0s 585us/step - loss: 0.0102 - mae: 0.0102

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes = True)

# %%
y_hat = model.predict(X_test)
plt.plot(y_test, y_hat, 'bo')
# Out:
# 324/324 [==============================] - 0s 322us/step

# %% [markdown]
# ## Second model

# %%
from keras import Sequential

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

# %%
n_feat = X_train.shape[1]

# %%
model = models.Sequential([
  layers.Dense(64,kernel_initializer='he_uniform', activation='elu', input_shape=(n_feat,)),
  layers.Dense(64,kernel_initializer='he_uniform', activation='elu'),
  layers.Dense(1, activation='linear')
])

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes = True)

# %%
from keras import optimizers
#model.compile(optimizer=optimizers.Adam(learning_rate=0.00001), loss='mse', metrics=['mae'])
model.compile(optimizer='sgd', loss='mse', metrics=['mae'])

# %%
num_epochs = 20
history = model.fit(X_train, y_train,
                    batch_size = 32, 
                    validation_split = 0.2, 
                    shuffle=True,
                    epochs=50)
# Out:
# Epoch 1/50
# 1037/1037 [==============================] - 1s 611us/step - loss: 0.0058 - mae: 0.0439 - val_loss: 0.0010 - val_mae: 0.0246
# Epoch 2/50
# 1037/1037 [==============================] - 1s 545us/step - loss: 7.6697e-04 - mae: 0.0218 - val_loss: 5.5929e-04 - val_mae: 0.0187
# Epoch 3/50
# 1037/1037 [==============================] - 1s 518us/step - loss: 5.0076e-04 - mae: 0.0177 - val_loss: 4.3366e-04 - val_mae: 0.0165
# Epoch 4/50
# 1037/1037 [==============================] - 1s 516us/step - loss: 3.9248e-04 - mae: 0.0157 - val_loss: 3.5468e-04 - val_mae: 0.0149
# Epoch 5/50
# 1037/1037 [==============================] - 1s 518us/step - loss: 3.3860e-04 - mae: 0.0146 - val_loss: 3.1096e-04 - val_mae: 0.0140
# Epoch 6/50
# 1037/1037 [==============================] - 1s 518us/step - loss: 3.0539e-04 - mae: 0.0139 - val_loss: 3.0265e-04 - val_mae: 0.0138
# Epoch 7/50
# 1037/1037 [==============================] - 1s 519us/step - loss: 2.8167e-04 - mae: 0.0133 - val_loss: 2.8685e-04 - val_mae: 0.0134
# Epoch 8/50
# 1037/1037 [==============================] - 1s 516us/step - loss: 2.6460e-04 - mae: 0.0129 - val_loss: 2.5670e-04 - val_mae: 0.0127
# Epoch 9/50
# 1037/1037 [==============================] - 1s 518us/step - loss: 2.5287e-04 - mae: 0.0126 - val_loss: 2.3763e-04 - val_mae: 0.0122
# Epoch 10/50
# 1037/1037 [==============================] - 1s 535us/step - loss: 2.4277e-04 - mae: 0.0124 - val_loss: 2.3759e-04 - val_mae: 0.0121
# Epoch 11/50
# 1037/1037 [==============================] - 1s 517us/step - loss: 2.3512e-04 - mae: 0.0122 - val_loss: 2.2915e-04 - val_mae: 0.0120
# Epoch 12/50
# 1037/1037 [==============================] - 1s 515us/step - loss: 2.2841e-04 - mae: 0.0120 - val_loss: 2.2468e-04 - val_mae: 0.0118
# Epoch 13/50
# 1037/1037 [==============================] - 1s 552us/step - loss: 1.8727e-04 - mae: 0.0109 - val_loss: 1.8066e-04 - val_mae: 0.0108
# Epoch 34/50
# 1037/1037 [==============================] - 1s 564us/step - loss: 1.8688e-04 - mae: 0.0109 - val_loss: 1.9157e-04 - val_mae: 0.0112
# Epoch 35/50
# 1037/1037 [==============================] - 1s 558us/step - loss: 1.8636e-04 - mae: 0.0109 - val_loss: 1.8405e-04 - val_mae: 0.0108
# Epoch 36/50
# 1037/1037 [==============================] - 1s 583us/step - loss: 1.8593e-04 - mae: 0.0109 - val_loss: 1.8698e-04 - val_mae: 0.0107
# Epoch 37/50
# 1037/1037 [==============================] - 1s 552us/step - loss: 1.8513e-04 - mae: 0.0109 - val_loss: 1.9669e-04 - val_mae: 0.0109
# Epoch 38/50
# 1037/1037 [==============================] - 1s 549us/step - loss: 1.8529e-04 - mae: 0.0109 - val_loss: 1.7832e-04 - val_mae: 0.0105
# Epoch 39/50
# 1037/1037 [==============================] - 1s 551us/step - loss: 1.8414e-04 - mae: 0.0108 - val_loss: 1.7603e-04 - val_mae: 0.0105
# Epoch 40/50
# 1037/1037 [==============================] - 1s 548us/step - loss: 1.8354e-04 - mae: 0.0108 - val_loss: 1.7914e-04 - val_mae: 0.0105
# Epoch 41/50
# 1037/1037 [==============================] - 1s 524us/step - loss: 1.8357e-04 - mae: 0.0108 - val_loss: 1.8125e-04 - val_mae: 0.0105
# Epoch 42/50
# 1037/1037 [==============================] - 1s 518us/step - loss: 1.8308e-04 - mae: 0.0108 - val_loss: 1.7893e-04 - val_mae: 0.0104
# Epoch 43/50
# 1037/1037 [==============================] - 1s 518us/step - loss: 1.8218e-04 - mae: 0.0108 - val_loss: 1.7748e-04 - val_mae: 0.0106
# Epoch 44/50
# 1037/1037 [==============================] - 1s 517us/step - loss: 1.8138e-04 - mae: 0.0108 - val_loss: 1.7966e-04 - val_mae: 0.0105
# Epoch 45/50
# 1037/1037 [==============================] - 1s 519us/step - loss: 1.8133e-04 - mae: 0.0108 - val_loss: 2.0115e-04 - val_mae: 0.0110
# Epoch 46/50
# 1037/1037 [==============================] - 1s 522us/step - loss: 1.8126e-04 - mae: 0.0108 - val_loss: 1.8274e-04 - val_mae: 0.0107
# Epoch 47/50
# 1037/1037 [==============================] - 1s 518us/step - loss: 1.8089e-04 - mae: 0.0107 - val_loss: 1.7796e-04 - val_mae: 0.0106
# Epoch 48/50
# 1037/1037 [==============================] - 1s 542us/step - loss: 1.8040e-04 - mae: 0.0107 - val_loss: 1.7137e-04 - val_mae: 0.0104
# Epoch 49/50
# 1037/1037 [==============================] - 1s 531us/step - loss: 1.8019e-04 - mae: 0.0107 - val_loss: 1.8121e-04 - val_mae: 0.0105
# Epoch 50/50
# 1037/1037 [==============================] - 1s 533us/step - loss: 1.8011e-04 - mae: 0.0107 - val_loss: 1.7504e-04 - val_mae: 0.0105

# %%
test_mse_score, test_mae_score = model.evaluate(X_test, y_test, verbose=0)

# %%
test_mae_score
# Out:
# 0.010680478997528553

# %%
y_hat = model.predict(X_test)
# Out:
# 324/324 [==============================] - 0s 321us/step

# %%
plt.plot(y_test, y_hat, 'bo')
