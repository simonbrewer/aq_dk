# %% [markdown]
# # Basis function construction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas
import datetime

# %% [markdown]
# Load monitor data

# %%
aq_df = pd.read_csv("./data/aqs_data.csv")
aq_df.head()
# Out:
#    site.num   latitude   longitude parameter.name              day_time  \
# 0      2005  40.598056 -111.894167          Ozone  2023-01-01T00:00:00Z
# 1      2005  40.598056 -111.894167          Ozone  2023-01-01T01:00:00Z
# 2      2005  40.598056 -111.894167          Ozone  2023-01-01T02:00:00Z
# 3      2005  40.598056 -111.894167          Ozone  2023-01-01T03:00:00Z
# 4      2005  40.598056 -111.894167          Ozone  2023-01-01T04:00:00Z
#
#          date      hour  sample.measurement
# 0  2023-01-01        0S               0.014
# 1  2023-01-01  1H 0M 0S               0.007
# 2  2023-01-01  2H 0M 0S               0.002
# 3  2023-01-01  3H 0M 0S               0.009
# 4  2023-01-01  4H 0M 0S               0.011

# %%
aq_df.shape
# Out:
# (51821, 8)

# %%
plt.plot(aq_df['longitude'], aq_df['latitude'], 'bo')

# %% [markdown]
# Load grid (we'll need to filter this down)

# %%
grid_gdf = geopandas.read_file("./data/coarse_grid_pts/grid_pts_coarse.shp")

# %%
grid_gdf.plot()
# Out:
# <Axes: >

# %%
grid_crds = grid_gdf.get_coordinates()
plt.plot(grid_crds['x'], grid_crds['y'], 'bo')
plt.plot(aq_df['longitude'], aq_df['latitude'], 'go')

# %%
ebus = pd.read_csv("./data/EBUS_TEST_DATA/BUS04_2023_06.csv", header = [0,1],  
                 na_values = -9999.00)

# %%
plt.plot(ebus['2B_Ozone_Concentration'])

# %% [markdown]
# ## Get limits and standarize

# %% [markdown]
# ### Coordinates

# %%
min_x = grid_crds.x.min()
max_x = grid_crds.x.max()
min_y = grid_crds.y.min()
max_y = grid_crds.y.max()
print(min_x, max_x, min_y, max_y)
# Out:
# -112.25516635714284 -111.55831564285714 40.419293290000006 40.916769710000004

# %%
lon = aq_df.values[:,2].astype('float64')
lat = aq_df.values[:,1].astype('float64')
normalized_lon = (lon-min_x)/(max_x - min_x)
normalized_lat = (lat-min_y)/(max_y-min_y)
N = lon.shape[0]
print(N)
# Out:
# 51821

# %% [markdown]
# ### Time

# %%
aq_df.head()
# Out:
#    site.num   latitude   longitude parameter.name              day_time  \
# 0      2005  40.598056 -111.894167          Ozone  2023-01-01T00:00:00Z
# 1      2005  40.598056 -111.894167          Ozone  2023-01-01T01:00:00Z
# 2      2005  40.598056 -111.894167          Ozone  2023-01-01T02:00:00Z
# 3      2005  40.598056 -111.894167          Ozone  2023-01-01T03:00:00Z
# 4      2005  40.598056 -111.894167          Ozone  2023-01-01T04:00:00Z
#
#          date      hour  sample.measurement
# 0  2023-01-01        0S               0.014
# 1  2023-01-01  1H 0M 0S               0.007
# 2  2023-01-01  2H 0M 0S               0.002
# 3  2023-01-01  3H 0M 0S               0.009
# 4  2023-01-01  4H 0M 0S               0.011

# %%
day_time = aq_df['day_time']
day_time = pd.to_datetime(day_time)
# add the timezone:

print(day_time[0:10])
print(day_time.dtype)
# Out:
# 0   2023-01-01 00:00:00+00:00
# 1   2023-01-01 01:00:00+00:00
# 2   2023-01-01 02:00:00+00:00
# 3   2023-01-01 03:00:00+00:00
# 4   2023-01-01 04:00:00+00:00
# 5   2023-01-01 05:00:00+00:00
# 6   2023-01-01 06:00:00+00:00
# 7   2023-01-01 07:00:00+00:00
# 8   2023-01-01 08:00:00+00:00
# 9   2023-01-01 09:00:00+00:00
# Name: day_time, dtype: datetime64[ns, UTC]
# datetime64[ns, UTC]

# %%
day_time = day_time.astype('int64') / 1e9 ## Time in nanoseconds

# %%
min_t = day_time.min()
max_t = day_time.max()
print(min_t, max_t)
# Out:
# 1672531200.0 1696114800.0

# %%
aq_df['day_time2'] = (day_time - min_t) / (max_t-min_t)
aq_df['day_time2']
# Out:
# 0        0.000000
# 1        0.000153
# 2        0.000305
# 3        0.000458
# 4        0.000611
#            ...
# 51816    0.999389
# 51817    0.999542
# 51818    0.999695
# 51819    0.999847
# 51820    1.000000
# Name: day_time2, Length: 51821, dtype: float64

# %% [markdown]
# ## Basis functions

# %% [markdown]
# ### Time

# %%
s = np.array(aq_df['day_time2']).reshape(len(aq_df),1)
print(s.shape)
N_data = len(aq_df)
N = N_data ## We have a separate N for the training + test data set (no testing at present)
print(N)
# Out:
# (51821, 1)
# 51821

# %% [markdown]
# We need to define:
# - Number of basis layers (3)
# - Number of knots per layer
# - S.D. for Gaussian function
#
# Then make a ragged array holding the knots on the normalized scale.
#
# Note that one of the previous examples has a very high number of temporal knots (~800) which is very computationally expensive

# %%
## time basis 
# num_basis = [10,15,45]
# std_arr = [0.4,0.2,0.1]
num_basis = [70,250,410]
std_arr = [0.2,0.09,0.009]

mu_knots = [np.linspace(0,1,int(i)) for i in num_basis]

# %%
mu_knots
# Out:
# [array([0.        , 0.01449275, 0.02898551, 0.04347826, 0.05797101,
#         0.07246377, 0.08695652, 0.10144928, 0.11594203, 0.13043478,
#         0.14492754, 0.15942029, 0.17391304, 0.1884058 , 0.20289855,
#         0.2173913 , 0.23188406, 0.24637681, 0.26086957, 0.27536232,
#         0.28985507, 0.30434783, 0.31884058, 0.33333333, 0.34782609,
#         0.36231884, 0.37681159, 0.39130435, 0.4057971 , 0.42028986,
#         0.43478261, 0.44927536, 0.46376812, 0.47826087, 0.49275362,
#         0.50724638, 0.52173913, 0.53623188, 0.55072464, 0.56521739,
#         0.57971014, 0.5942029 , 0.60869565, 0.62318841, 0.63768116,
#         0.65217391, 0.66666667, 0.68115942, 0.69565217, 0.71014493,
#         0.72463768, 0.73913043, 0.75362319, 0.76811594, 0.7826087 ,
#         0.79710145, 0.8115942 , 0.82608696, 0.84057971, 0.85507246,
#         0.86956522, 0.88405797, 0.89855072, 0.91304348, 0.92753623,
#         0.94202899, 0.95652174, 0.97101449, 0.98550725, 1.        ]),
#  array([0.        , 0.00401606, 0.00803213, 0.01204819, 0.01606426,
#         0.02008032, 0.02409639, 0.02811245, 0.03212851, 0.03614458,
#         0.04016064, 0.04417671, 0.04819277, 0.05220884, 0.0562249 ,
#         0.06024096, 0.06425703, 0.06827309, 0.07228916, 0.07630522,
#         0.08032129, 0.08433735, 0.08835341, 0.09236948, 0.09638554,
#         0.10040161, 0.10441767, 0.10843373, 0.1124498 , 0.11646586,
#         0.12048193, 0.12449799, 0.12851406, 0.13253012, 0.13654618,
#         0.14056225, 0.14457831, 0.14859438, 0.15261044, 0.15662651,
#         0.16064257, 0.16465863, 0.1686747 , 0.17269076, 0.17670683,
#         0.18072289, 0.18473896, 0.18875502, 0.19277108, 0.19678715,
#         0.57457213, 0.57701711, 0.5794621 , 0.58190709, 0.58435208,
#         0.58679707, 0.58924205, 0.59168704, 0.59413203, 0.59657702,
#         0.599022  , 0.60146699, 0.60391198, 0.60635697, 0.60880196,
#         0.61124694, 0.61369193, 0.61613692, 0.61858191, 0.62102689,
#         0.62347188, 0.62591687, 0.62836186, 0.63080685, 0.63325183,
#         0.63569682, 0.63814181, 0.6405868 , 0.64303178, 0.64547677,
#         0.64792176, 0.65036675, 0.65281174, 0.65525672, 0.65770171,
#         0.6601467 , 0.66259169, 0.66503667, 0.66748166, 0.66992665,
#         0.67237164, 0.67481663, 0.67726161, 0.6797066 , 0.68215159,
#         0.68459658, 0.68704156, 0.68948655, 0.69193154, 0.69437653,
#         0.69682152, 0.6992665 , 0.70171149, 0.70415648, 0.70660147,
#         0.70904645, 0.71149144, 0.71393643, 0.71638142, 0.71882641,
#         0.72127139, 0.72371638, 0.72616137, 0.72860636, 0.73105134,
#         0.73349633, 0.73594132, 0.73838631, 0.7408313 , 0.74327628,
#         0.74572127, 0.74816626, 0.75061125, 0.75305623, 0.75550122,
#         0.75794621, 0.7603912 , 0.76283619, 0.76528117, 0.76772616,
#         0.77017115, 0.77261614, 0.77506112, 0.77750611, 0.7799511 ,
#         0.78239609, 0.78484108, 0.78728606, 0.78973105, 0.79217604,
#         0.79462103, 0.79706601, 0.799511  , 0.80195599, 0.80440098,
#         0.80684597, 0.80929095, 0.81173594, 0.81418093, 0.81662592,
#         0.8190709 , 0.82151589, 0.82396088, 0.82640587, 0.82885086,
#         0.83129584, 0.83374083, 0.83618582, 0.83863081, 0.84107579,
#         0.84352078, 0.84596577, 0.84841076, 0.85085575, 0.85330073,
#         0.85574572, 0.85819071, 0.8606357 , 0.86308068, 0.86552567,
#         0.86797066, 0.87041565, 0.87286064, 0.87530562, 0.87775061,
#         0.8801956 , 0.88264059, 0.88508557, 0.88753056, 0.88997555,
#         0.89242054, 0.89486553, 0.89731051, 0.8997555 , 0.90220049,
#         0.90464548, 0.90709046, 0.90953545, 0.91198044, 0.91442543,
#         0.91687042, 0.9193154 , 0.92176039, 0.92420538, 0.92665037,
#         0.92909535, 0.93154034, 0.93398533, 0.93643032, 0.93887531,
#         0.94132029, 0.94376528, 0.94621027, 0.94865526, 0.95110024,
#         0.95354523, 0.95599022, 0.95843521, 0.9608802 , 0.96332518,
#         0.96577017, 0.96821516, 0.97066015, 0.97310513, 0.97555012,
#         0.97799511, 0.9804401 , 0.98288509, 0.98533007, 0.98777506,
#         0.99022005, 0.99266504, 0.99511002, 0.99755501, 1.        ])]

# %% [markdown]
# Now create the basis functions. This does the following:
# - Loop over each basis layer
# - Loop by knot in the selected layer
# - Get distance from each observation (held in `s`) to the knot
# - Estimate Gaussian weight

# %%
phi_t = np.zeros((N, sum(num_basis)))
K = 0
for res in range(len(num_basis)):
    std = std_arr[res]
    for i in range(num_basis[res]):
        d = np.square(np.absolute(s-mu_knots[res][i]))
        for j in range(len(d)):
            if d[j] >= 0 and d[j] <= 1:
                phi_t[j,i + K] = np.exp(-0.5 * d[j]/(std**2))
            else:
                phi_t[j,i + K] = 0
    K = K + num_basis[res]
# Out:
# /var/folders/ws/m03sh3xd4ns621mckfrht3r0000_08/T/ipykernel_77173/420065419.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   phi_t[j,i + K] = np.exp(-0.5 * d[j]/(std**2))

# %% [markdown]
# Plot basis functions at location (time) 0

# %%
plt.plot(phi_t[0,:])
#plt.plot(phi_t[25000,:])
plt.show()

# %% [markdown]
# Plot first basis function (over all time)

# %%
plt.plot(phi_t[:,0])

# %% [markdown]
# ### Space

# %%
s = np.vstack((normalized_lon,normalized_lat)).T

# %%
## Knots for spatial dimension (from STDK example)
num_basis = [5**2,9**2,11**2]
knots_1d = [np.linspace(0,1,int(np.sqrt(i))) for i in num_basis]

# %%
##Wendland kernel
K = 0
phi = np.zeros((N, sum(num_basis)))
for res in range(len(num_basis)):
    theta = 1/np.sqrt(num_basis[res])*2.5
    knots_s1, knots_s2 = np.meshgrid(knots_1d[res],knots_1d[res])
    knots = np.column_stack((knots_s1.flatten(),knots_s2.flatten()))
    for i in range(num_basis[res]):
        d = np.linalg.norm(s-knots[i,:],axis=1)/theta
        for j in range(len(d)):
            if d[j] >= 0 and d[j] <= 1:
                phi[j,i + K] = (1-d[j])**6 * (35 * d[j]**2 + 18 * d[j] + 3)/3
            else:
                phi[j,i + K] = 0
    K = K + num_basis[res]

# %% [markdown]
# Basis function for first location

# %%
plt.plot(phi[0,:])

# %%
x = phi[0,0:25]
x = x.reshape(5, 5)

# %%
plt.imshow(x, extent=[1, 0, 1, 0])
plt.plot(normalized_lon[0], normalized_lat[0], 'bo')
plt.show()

# %%
num_basis
# Out:
# [25, 81, 121]

# %%
x = phi[0,25:106]
x = x.reshape(9, 9)
plt.imshow(x, extent=[1, 0, 1, 0])
plt.plot(normalized_lon[0], normalized_lat[0], 'bo')
plt.show()

# %%
x = phi[0,106:227]
x = x.reshape(11, 11)
plt.imshow(x, extent=[1, 0, 1, 0])
plt.plot(normalized_lon[0], normalized_lat[0], 'bo')
plt.show()

# %% [markdown]
# Check dimensions and stack (column bind)

# %%
print(phi_t.shape)
print(phi.shape)

phi2 = np.hstack((phi_t,phi))
# Out:
# (51821, 730)
# (51821, 227)

# %% [markdown]
# Remove any columns with all zeros (basis functions not linked to obs)

# %%
idx_zero = np.array([], dtype=int)
for i in range(phi2.shape[1]):
    if sum(phi2[:,i]!=0)==0:
        idx_zero = np.append(idx_zero,int(i))

phi_reduce = np.delete(phi2,idx_zero,1)
print(phi2.shape)
print(phi_reduce.shape)
# Out:
# (51821, 957)
# (51821, 861)

# %% [markdown]
# Write out

# %%
np.save("./rbfs/phi_full.npy", phi2)
np.save("./rbfs/phi_reduce.npy", phi_reduce)

# %%
df = pd.DataFrame(phi2)
df = pd.DataFrame(phi_reduce)
df.to_csv("./rbfs/phi_reduce.csv")

# %%
y = np.array(aq_df["sample.measurement"])
np.save("./rbfs/y.npy", y)
#y.min()

# %%
plt.plot(y)

# %%
df_y = pd.DataFrame(y)
#df_y.to_csv("./rbfs/y.csv")

# %%
df_y[0]
# Out:
# 0        0.014
# 1        0.007
# 2        0.002
# 3        0.009
# 4        0.011
#          ...
# 51816    0.020
# 51817    0.028
# 51818    0.038
# 51819    0.044
# 51820    0.040
# Name: 0, Length: 51821, dtype: float64

# %%
df = pd.DataFrame(phi2)
df['y'] = df_y[0]
df['site'] = aq_df['site.num']
df['date'] = aq_df['date']
df.to_csv("./rbfs/phi_full.csv")
df = pd.DataFrame(phi_reduce)
df['y'] = df_y[0]
df['site'] = aq_df['site.num']
df['date'] = aq_df['date']
df.to_csv("./rbfs/phi_reduce.csv")

# %%
phi2.shape
# Out:
# (51821, 957)
